# %%
#import pandas package
import pandas as pd

# %%
#creating series using a list of values
s1 = pd.Series([10,20,30,40,50])

# %%
print("The series values are:", s1.values)
print("The index values are:", s1.index.values)
# Out:
# The series values are: [10 20 30 40 50]
# The index values are: [0 1 2 3 4]

# %%
#defining custom indexes 
s2 = pd.Series([80,93,78,85,97], index=['English','Science','physical education','Maths','Social'])

# %%
print("The Scores obtained by the student are", s2)
# Out:
# The Scores obtained by the student are English               80
# Science               93
# physical education    78
# Maths                 85
# Social                97
# dtype: int64

# %%
#defining series values and index values
s2.name = 'Student Scores'
s2.index.name = 'Subject'

# %%
print("The scores obtained by the student - subjectwise:\n", s2)
# Out:
# The scores obtained by the student - subjectwise:
#  Subject
# English               80
# Science               93
# physical education    78
# Maths                 85
# Social                97
# Name: Student Scores, dtype: int64

# %%
#subsetting series

# %%
s2[0]
# Out:
# 80

# %%
#slicing using default integer index
s1[1:4]
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#slicing using string index
s2['Science']
# Out:
# 93

# %%
#Creating series from dictionary

# %%
dict_fruits = { 'Orange':80,
              'Apples':210,
              'Bananas':50,
              'Grapes':90,
              'Watermelon':70}

# %%
#converting dictionary into series 
fruits = pd.Series(dict_fruits)

# %%
print("fruits and prices\n", fruits)
# Out:
# fruits and prices
#  Orange         80
# Apples        210
# Bananas        50
# Grapes         90
# Watermelon     70
# dtype: int64

# %%
#slicing series to retrieve price of fruit
print("The price of fruit per kg of Apples is:", fruits['Apples'] )
# Out:
# The price of fruit per kg of Apples is: 210

# %%
#creating Data frame from series object
df_scores = pd.DataFrame(s2, columns=['Student1'])

# %%
print("The dataframe created from series is\n",df_scores)
# Out:
# The dataframe created from series is
#  Empty DataFrame
# Columns: [Student1]
# Index: []

# %%
#creating dataframe from dictionary

# %%
#create height series in feet
height = pd.Series([5.3,6.2,5.8,5.0,5.5], index=['Person 1','Person 2','Person 3','Person 4','Person 5'])

#creating weight series in kgs
weight = pd.Series([65,89,75,60,59], index=['Person 1','Person 2','Person 3','Person 4','Person 5'])

# %%
#create dataframe
df_person = pd.DataFrame({'height': height, 'weight': weight})

print("The person table details are:\n", df_person)
# Out:
# The person table details are:
#            height  weight
# Person 1     5.3      65
# Person 2     6.2      89
# Person 3     5.8      75
# Person 4     5.0      60
# Person 5     5.5      59

# %%
#slicing the series
print("here is the info:", height['Person 1'], weight['Person 1'])
# Out:
# here is the info: 5.3 65

# %%
#creating dataframe by importing data from file

# %%
#read data from .csv file
data = pd.read_csv('IMDB-Movie-Data.csv')

#read data with specified explicit index
data_indexed = pd.read_csv('IMDB-Movie-Data.csv', index_col="Title")

# %%
#understanding basic info about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
#preview top 5 rows using head
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
#checking for null values
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
#extract data as series
genre = data['Genre']

# %%
genre
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
title = data['Title']

# %%
title
# Out:
# 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: Title, Length: 1000, dtype: object

# %%
director = data['Director']

# %%
director
# Out:
# 0                James Gunn
# 1              Ridley Scott
# 2        M. Night Shyamalan
# 3      Christophe Lourdelet
# 4                David Ayer
#                ...
# 995               Billy Ray
# 996                Eli Roth
# 997              Jon M. Chu
# 998          Scot Armstrong
# 999        Barry Sonnenfeld
# Name: Director, Length: 1000, dtype: object

# %%
type(genre)
# Out:
# pandas.core.series.Series

# %%
#extract data as dataframe
data[['Genre']]
# Out:
#                         Genre
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %%
type(data[['Genre']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['Title']]
# Out:
#                        Title
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# ..                       ...
# 995     Secret in Their Eyes
# 996          Hostel: Part II
# 997   Step Up 2: The Streets
# 998             Search Party
# 999               Nine Lives
#
# [1000 rows x 1 columns]

# %%
data[['Director']]
# Out:
#                  Director
# 0              James Gunn
# 1            Ridley Scott
# 2      M. Night Shyamalan
# 3    Christophe Lourdelet
# 4              David Ayer
# ..                    ...
# 995             Billy Ray
# 996              Eli Roth
# 997            Jon M. Chu
# 998        Scot Armstrong
# 999      Barry Sonnenfeld
#
# [1000 rows x 1 columns]

# %%
#extracting from multiple columns
some_cols = data[['Title','Genre','Actors','Director','Rating']]

# %%
some_cols.head()
# Out:
#                      Title                     Genre  \
# 0  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1               Prometheus  Adventure,Mystery,Sci-Fi
# 2                    Split           Horror,Thriller
# 3                     Sing   Animation,Comedy,Family
# 4            Suicide Squad  Action,Adventure,Fantasy
#
#                                               Actors              Director  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...            James Gunn
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...          Ridley Scott
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...    M. Night Shyamalan
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  Christophe Lourdelet
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...            David Ayer
#
#    Rating
# 0     8.1
# 1     7.0
# 2     7.3
# 3     7.2
# 4     6.2

# %%
some_cols.tail()
# Out:
#                       Title                  Genre  \
# 995    Secret in Their Eyes    Crime,Drama,Mystery
# 996         Hostel: Part II                 Horror
# 997  Step Up 2: The Streets    Drama,Music,Romance
# 998            Search Party       Adventure,Comedy
# 999              Nine Lives  Comedy,Family,Fantasy
#
#                                                 Actors          Director  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...         Billy Ray
# 996  Lauren German, Heather Matarazzo, Bijou Philli...          Eli Roth
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...        Jon M. Chu
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...    Scot Armstrong
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  Barry Sonnenfeld
#
#      Rating
# 995     6.2
# 996     5.5
# 997     6.2
# 998     5.6
# 999     5.3

# %%
#extracting data by row index

# %%
data_indexed.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
#retrieving movie data with title using loc
data_indexed.loc['Sing']
# Out:
# Rank                                                                  4
# Genre                                           Animation,Comedy,Family
# Description           In a city of humanoid animals, a hustling thea...
# Director                                           Christophe Lourdelet
# Actors                Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Year                                                               2016
# Runtime (Minutes)                                                   108
# Rating                                                              7.2
# Votes                                                             60545
# Revenue (Millions)                                               270.32
# Metascore                                                          59.0
# Name: Sing, dtype: object

# %%
data_indexed.loc['Suicide Squad']
# Out:
# Rank                                                                  5
# Genre                                          Action,Adventure,Fantasy
# Description           A secret government agency recruits some of th...
# Director                                                     David Ayer
# Actors                Will Smith, Jared Leto, Margot Robbie, Viola D...
# Year                                                               2016
# Runtime (Minutes)                                                   123
# Rating                                                              6.2
# Votes                                                            393727
# Revenue (Millions)                                               325.02
# Metascore                                                          40.0
# Name: Suicide Squad, dtype: object

# %%
#dataframe retrieval
data_indexed.loc[['Sing']][['Genre','Actors','Director','Rating','Revenue (Millions)']]
# Out:
#                          Genre  \
# Title
# Sing   Animation,Comedy,Family
#
#                                                   Actors  \
# Title
# Sing   Matthew McConaughey,Reese Witherspoon, Seth Ma...
#
#                    Director  Rating  Revenue (Millions)
# Title
# Sing   Christophe Lourdelet     7.2              270.32

# %%
data_indexed.loc[['Suicide Squad']][['Genre','Actors','Director','Rating','Revenue (Millions)']]
# Out:
#                                   Genre  \
# Title
# Suicide Squad  Action,Adventure,Fantasy
#
#                                                           Actors    Director  \
# Title
# Suicide Squad  Will Smith, Jared Leto, Margot Robbie, Viola D...  David Ayer
#
#                Rating  Revenue (Millions)
# Title
# Suicide Squad     6.2              325.02

# %%
#retrieving data with row indices uisng iloc
#pick rows from indexes 10-49

data.iloc[10:20]
# Out:
#     Rank                                    Title                       Genre  \
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# 12    13                                Rogue One     Action,Adventure,Sci-Fi
# 13    14                                    Moana  Animation,Adventure,Comedy
# 14    15                                 Colossal         Action,Comedy,Drama
# 15    16                  The Secret Life of Pets  Animation,Adventure,Comedy
# 16    17                            Hacksaw Ridge     Biography,Drama,History
# 17    18                             Jason Bourne             Action,Thriller
# 18    19                                     Lion             Biography,Drama
# 19    20                                  Arrival        Drama,Mystery,Sci-Fi
#
#                                           Description          Director  \
# ...

# %%
#dataframe retrieval
data.iloc[10:20][['Title','Rating','Revenue (Millions)']]
# Out:
#                                       Title  Rating  Revenue (Millions)
# 10  Fantastic Beasts and Where to Find Them     7.5              234.02
# 11                           Hidden Figures     7.8              169.27
# 12                                Rogue One     7.9              532.17
# 13                                    Moana     7.7              248.75
# 14                                 Colossal     6.4                2.87
# 15                  The Secret Life of Pets     6.6              368.31
# 16                            Hacksaw Ridge     8.2               67.12
# 17                             Jason Bourne     6.7              162.16
# 18                                     Lion     8.1               51.69
# 19                                  Arrival     8.0              100.50

# %%
#data selection based on conditional filtering
import numpy as np

# %%
#retrieving data for minimun and maximum rating from dataset
rating_min = np.where(data['Rating'] == min(data['Rating']))
data.iloc[rating_min][['Title','Actors','Director','Year','Rating']]
# Out:
#               Title                                             Actors  \
# 829  Disaster Movie  Carmen Electra, Vanessa Lachey,Nicole Parker, ...
#
#             Director  Year  Rating
# 829  Jason Friedberg  2008     1.9

# %%
rating_max = np.where(data['Rating'] == max(data['Rating']))
data.iloc[rating_max][['Title','Actors','Director','Year','Rating']]
# Out:
#               Title                                             Actors  \
# 54  The Dark Knight  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...
#
#              Director  Year  Rating
# 54  Christopher Nolan  2008     9.0

# %%
#retrieving data for movies released from 2010-2016 with ratings less than 6.0 but topped in terms of revenue
data[((data['Year'] >= 2010) & (data['Year'] <= 2016))
    & (data['Rating'] < 6.0)
    & (data['Revenue (Millions)'] > data['Revenue (Millions)'].quantile(0.95))]
# Out:
#      Rank                       Title                    Genre  \
# 941   942  The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
#
#                                            Description     Director  \
# 941  As a string of mysterious killings grips Seatt...  David Slade
#
#                                                 Actors  Year  \
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 941                124     4.9  192740              300.52       58.0

# %%
#get unique values in rating column
data['Director'].unique()
# Out:
# array(['James Gunn', 'Ridley Scott', 'M. Night Shyamalan',
#        'Christophe Lourdelet', 'David Ayer', 'Yimou Zhang',
#        'Damien Chazelle', 'Sean Foley', 'James Gray', 'Morten Tyldum',
#        'David Yates', 'Theodore Melfi', 'Gareth Edwards', 'Ron Clements',
#        'Nacho Vigalondo', 'Chris Renaud', 'Mel Gibson', 'Paul Greengrass',
#        'Garth Davis', 'Denis Villeneuve', 'Stephen Gaghan',
#        'Kenneth Lonergan', 'Ben Young', 'Walt Dohrn', 'Roland Emmerich',
#        'Dominique Abel', 'S.S. Rajamouli', 'Phillip Guzman', 'Jon Lucas',
#        'Justin Kurzel', 'John Hamburg', 'Tom Ford', 'Bryan Singer',
#        'Tim Miller', 'Paul W.S. Anderson', 'Anthony Russo',
#        'Christopher Nolan', 'Scott Derrickson', 'Antoine Fuqua',
#        'Patrick Read Johnson', 'Greg Tiernan', 'Barry Jenkins',
#        'Shawn Burkett', 'John Lee Hancock', 'Ricardo de Montreuil',
#        'Rob Marshall', 'John Madden', 'Scott Hicks', 'Justin Lin',
# ...

# %%
data['Director'].value_counts()
# Out:
# Ridley Scott          8
# Michael Bay           6
# Paul W.S. Anderson    6
# David Yates           6
# M. Night Shyamalan    6
#                      ..
# Etan Cohen            1
# Terry Gilliam         1
# Mario Van Peebles     1
# Todor Chapkanov       1
# Ari Sandel            1
# Name: Director, Length: 644, dtype: int64

# %%
#groupby operations
#data is grouped by 'Director' column and then aggregation 'sum' is applied.
data.groupby('Director').sum()
# Out:
#                      Rank   Year  Runtime (Minutes)  Rating    Votes  \
# Director
# Aamir Khan            992   2007                165     8.5   102697
# Abdellatif Kechiche   312   2013                180     7.8   103150
# Adam Leon             784   2016                 82     6.5     1031
# Adam McKay           1910   8039                443    28.0   806827
# Adam Shankman        1460   4019                240    12.6   167467
# ...                   ...    ...                ...     ...      ...
# Xavier Dolan         1588   4030                236    15.1    44218
# Yimou Zhang             6   2016                103     6.1    56036
# Yorgos Lanthimos      479   4024                213    14.4   172259
# Zack Snyder           904  10055                683    35.2  2301544
# Zackary Adler         605   2015                110     5.1     1630
#
#                      Revenue (Millions)  Metascore
# Director
# Aamir Khan                         1.20       42.0
# ...

# %%
#applying aggregation to specfic selected attribute in dataset
data.groupby('Director')[['Rating']].mean().head()
# Out:
#                      Rating
# Director
# Aamir Khan              8.5
# Abdellatif Kechiche     7.8
# Adam Leon               6.5
# Adam McKay              7.0
# Adam Shankman           6.3

# %%
data.groupby('Director')[['Rating']].mean().tail()
# Out:
#                   Rating
# Director
# Xavier Dolan        7.55
# Yimou Zhang         6.10
# Yorgos Lanthimos    7.20
# Zack Snyder         7.04
# Zackary Adler       5.10

# %%
#sorting
data.groupby('Director')[['Rating']].mean().sort_values(['Rating'], ascending=False).head(5)
# Out:
#                                   Rating
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Makoto Shinkai                      8.60
# Olivier Nakache                     8.60
# Florian Henckel von Donnersmarck    8.50

# %%
data.groupby('Director')[['Rating']].mean().sort_values(['Rating'], ascending=True).head(5)
# Out:
#                    Rating
# Director
# Jason Friedberg       1.9
# James Wong            2.7
# Shawn Burkett         2.7
# Jonathan Holbrook     3.2
# Femi Oyeniran         3.5

# %%
data.sort_values(['Revenue (Millions)','Rating'], ascending=False).head(5)
# Out:
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
# 87    88                                      Avatar
# 85    86                              Jurassic World
# 76    77                                The Avengers
# 54    55                             The Dark Knight
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
# 87  Action,Adventure,Fantasy
# 85   Action,Adventure,Sci-Fi
# 76             Action,Sci-Fi
# 54        Action,Crime,Drama
#
#                                           Description           Director  \
# 50  Three decades after the defeat of the Galactic...        J.J. Abrams
# 87  A paraplegic marine dispatched to the moon Pan...      James Cameron
# 85  A new theme park, built on the original site o...    Colin Trevorrow
# 76  Earth's mightiest heroes must come together an...        Joss Whedon
# 54  When the menace known as the Joker wreaks havo...  Christopher Nolan
#
# ...

# %%
#dealing with missing values
data.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
#check null values row-wise
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
#drop all rows with missing data
data.dropna()
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#drop all columns with missing data
data.dropna(axis=1)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#using thresh parameter to specify the minimum number of non null values for the column/row to be held without dropping
data.dropna(axis=0, thresh=6)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#using drop function to drop columns
data.drop('Metascore', axis=1).head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#using fillna()

# %%
revenue_mean = data_indexed['Revenue (Millions)'].mean()
print("The mean revenue is: ", revenue_mean)
# Out:
# The mean revenue is:  82.95637614678897

# %%
#fill the null value with this mean revenue
data_indexed['Revenue (Millions)'].fillna(revenue_mean, inplace=True)

# %%
data_indexed.isnull().sum()
# Out:
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
#classification of movies based on ratings
def rating_group(rating):
    if rating >= 7.5:
        return 'Good'
    elif rating >= 6.0:
        return 'Average'
    else:
        return 'Bad'

# %%
#applying this function on movies data
#creating a new variable in the dataset to hold the rating category
data['Rating_category'] = data['Rating'].apply(rating_group)

# %%
data[['Title','Director','Rating','Rating_category']].head(5)
# Out:
#                      Title              Director  Rating Rating_category
# 0  Guardians of the Galaxy            James Gunn     8.1            Good
# 1               Prometheus          Ridley Scott     7.0         Average
# 2                    Split    M. Night Shyamalan     7.3         Average
# 3                     Sing  Christophe Lourdelet     7.2         Average
# 4            Suicide Squad            David Ayer     6.2         Average

# %%
data[['Title','Director','Rating','Rating_category']].tail(5)
# Out:
#                       Title          Director  Rating Rating_category
# 995    Secret in Their Eyes         Billy Ray     6.2         Average
# 996         Hostel: Part II          Eli Roth     5.5             Bad
# 997  Step Up 2: The Streets        Jon M. Chu     6.2         Average
# 998            Search Party    Scot Armstrong     5.6             Bad
# 999              Nine Lives  Barry Sonnenfeld     5.3             Bad

# %%
data_indexed.pivot_table('Revenue (Millions)', index='Director', aggfunc='sum', columns='Year').head(10)
# Out:
# Year                   2006    2007    2008  2009    2010  2011   2012  2013  \
# Director
# Aamir Khan              NaN    1.20     NaN   NaN     NaN   NaN    NaN   NaN
# Abdellatif Kechiche     NaN     NaN     NaN   NaN     NaN   NaN    NaN   2.2
# Adam Leon               NaN     NaN     NaN   NaN     NaN   NaN    NaN   NaN
# Adam McKay           148.21     NaN  100.47   NaN  119.22   NaN    NaN   NaN
# Adam Shankman           NaN  118.82     NaN   NaN     NaN   NaN  38.51   NaN
# Adam Wingard            NaN     NaN     NaN   NaN     NaN   NaN    NaN   NaN
# Afonso Poyart           NaN     NaN     NaN   NaN     NaN   NaN    NaN   NaN
# Aisling Walsh           NaN     NaN     NaN   NaN     NaN   NaN    NaN   NaN
# Akan Satayev            NaN     NaN     NaN   NaN     NaN   NaN    NaN   NaN
# Akiva Schaffer          NaN     NaN     NaN   NaN     NaN   NaN    NaN   NaN
#
# Year                 2014       2015       2016
# Director
# Aamir Khan            NaN        NaN        NaN
# ...
